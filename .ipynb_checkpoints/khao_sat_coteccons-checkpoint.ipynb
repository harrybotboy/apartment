# %% [markdown]
# ## GIỚI THIỆU

# %% [markdown]
# ### MỤC TIÊU
# Mục đích của nghiên cứu là để dẫn chứng cho các nội dung như nhận thức, quan điểm về tiêu chí đánh giá lựa chọn nhà thầu, yếu tố ảnh hưởng đến quyết định sở hữu căn hộ chung cư, tiêu chí lựa chọn diện tích sở hữu căn hộ, các tiện ích cũng như không gian thiết kế.
#
# Nghiên cứu này sẽ phân tích dữ liệu và trả lời cho các câu hỏi:
# 1. Tiêu chí đánh giá lựa chọn nhà thầu
# 2. Yếu tố ảnh hưởng đến quyết định sở hữu căn hộ chung cư
# 3. Tiêu chí lựa chọn diện tích sở hữu căn hộ
# 4. Các tiện ích cũng như không gian thiết kế.
#
# ### DỮ LIỆU
# Nguồn dữ liệu: Bảng kết quả khảo sát tại file `khao_sat_coteccons_200.csv`.
#
# ### PHÂN TÍCH
#
# In this section, descriptive statistics and data visualization techniques will be employed to understand the data better. Statistical inference will also be used to test if the observed values are statistically significant. Some of the key metrics that will be computed include:
# 1.
#
# Distributio2. ns
# cou3. nts
# relationship between spe4. cies
# conservation status of sp5. ecies
# observations of species in
#
# ### ĐÁNH GIÁ
#
#  parks.nal.k

# %% [markdown]
# ### HIỂN THỊ DỮ LIỆU TRONG BẢNG

# %%
# Import Python modules
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

from scipy.stats import chi2_contingency

from matplotlib.colors import ListedColormap, Normalize

# %%
apartment = pd.read_csv('khao_sat_coteccons_200.csv',encoding='utf-8')
apartment.head(10)
# Out:
#   Giới tính               Độ tuổi          Nghề nghiệp Tình trạng hôn nhân  \
# 0        Nữ  Từ 30 – dưới 40 tuổi                 Khác          Đã kết hôn
# 1       Nam  Từ 22 – dưới 30 tuổi  Nhân viên văn phòng            Độc thân
# 2       Nam  Từ 22 – dưới 30 tuổi  Nhân viên văn phòng            Độc thân
# 3        Nữ  Từ 30 – dưới 40 tuổi  Nhân viên văn phòng            Độc thân
# 4       Nam  Từ 22 – dưới 30 tuổi  Nhân viên văn phòng            Độc thân
# 5        Nữ  Từ 30 – dưới 40 tuổi  Nhân viên văn phòng            Độc thân
# 6        Nữ  Từ 22 – dưới 30 tuổi              Nội trợ            Độc thân
# 7       Nam  Từ 30 – dưới 40 tuổi  Nhân viên văn phòng            Độc thân
# 8       Nam  Từ 30 – dưới 40 tuổi              Nội trợ          Đã kết hôn
# 9       Nam          Trên 40 tuổi  Nhân viên văn phòng          Đã kết hôn
#
#   Thu nhập hàng tháng Đã từng/sở hữu nhà chung cư  \
# 0       Trên 30 triệu                     Đã từng
# 1      Từ 15-20 triệu                   Chưa từng
# 2      Từ 20-30 triệu                   Chưa từng
# 3       Trên 30 triệu                   Chưa từng
# 4      Từ 10-15 triệu                   Chưa từng
# 5      Từ 10-15 triệu                   Chưa từng
# 6      Từ 15-20 triệu                   Chưa từng
# 7      Từ 20-30 triệu                   Chưa từng
# 8       Trên 30 triệu                   Chưa từng
# 9      Từ 15-20 triệu                   Chưa từng
#
#       Lý do chọn sở hữu chung cư    Loại căn hộ muốn sở hữu  \
# 0                   Mua cho thuê          Shophouse (>90m2)
# 1                     Mua đầu tư  Căn hộ 2 phòng ngủ (60m2)
# 2  Mong muốn sở hữu căn hộ riêng          Shophouse (>90m2)
# 3                 Mua kinh doanh  Căn hộ 1 phòng ngủ (40m2)
# 4  Mong muốn sở hữu căn hộ riêng  Căn hộ 1 phòng ngủ (40m2)
# 5                     Mua đầu tư  Căn hộ 1 phòng ngủ (40m2)
# 6                 Mua kinh doanh  Căn hộ 2 phòng ngủ (60m2)
# 7                     Mua đầu tư  Căn hộ 2 phòng ngủ (60m2)
# 8                   Mua cho thuê  Căn hộ 2 phòng ngủ (60m2)
# 9                 Mua kinh doanh          Shophouse (>90m2)
#
#          Nguồn thông tin về căn hộ  Thi công an toàn  Bàn giao đúng tiến độ  \
# 0            Báo chí, truyền thông                 9                     10
# 1            Báo chí, truyền thông                 2                      9
# 2            Báo chí, truyền thông                 7                      8
# 3            Báo chí, truyền thông                 9                      8
# 4            Báo chí, truyền thông                 1                     10
# 5            Báo chí, truyền thông                 8                      8
# 6            Báo chí, truyền thông                 2                      4
# 7            Báo chí, truyền thông                 9                      7
# 8  Người thân, bạn bè, đồng nghiệp                 5                      5
# 9            Báo chí, truyền thông                 6                      4
#
#    Thiết kế đẹp  Uy tín doanh nghiệp  Chất lượng dịch vụ bảo trì và sửa chữa  \
# 0             8                    6                                       8
# 1             0                    2                                       0
# 2             5                    7                                       0
# 3             9                    8                                       3
# 4             6                    3                                       6
# 5             4                    3                                       2
# 6             8                   10                                       8
# 7             6                    5                                       0
# 8             1                    8                                       3
# 9             3                    9                                       7
#
#    Chất lượng thi công  Thiết kế tổng thể  Chi phí sở hữu
# 0                    3                  5               6
# 1                    7                  6               5
# 2                    9                  6               6
# 3                    3                  7               4
# 4                    5                  7               9
# 5                    3                  7               3
# 6                    2                  9               3
# 7                    7                  5               5
# 8                    7                  8               1
# 9                    7                  5               6

# %%
print(apartment.columns)
print(apartment.dtypes)
# Out:
# Index(['Giới tính', 'Độ tuổi', 'Nghề nghiệp', 'Tình trạng hôn nhân',
#        'Thu nhập hàng tháng', 'Đã từng/sở hữu nhà chung cư',
#        'Lý do chọn sở hữu chung cư', 'Loại căn hộ muốn sở hữu',
#        'Nguồn thông tin về căn hộ', 'Thi công an toàn',
#        'Bàn giao đúng tiến độ', 'Thiết kế đẹp', 'Uy tín doanh nghiệp',
#        'Chất lượng dịch vụ bảo trì và sửa chữa', 'Chất lượng thi công',
#        'Thiết kế tổng thể', 'Chi phí sở hữu'],
#       dtype='object')
# Giới tính                                 object
# Độ tuổi                                   object
# Nghề nghiệp                               object
# Tình trạng hôn nhân                       object
# Thu nhập hàng tháng                       object
# Đã từng/sở hữu nhà chung cư               object
# Lý do chọn sở hữu chung cư                object
# Loại căn hộ muốn sở hữu                   object
# Nguồn thông tin về căn hộ                 object
# Thi công an toàn                           int64
# Bàn giao đúng tiến độ                      int64
# Thiết kế đẹp                               int64
# Uy tín doanh nghiệp                        int64
# Chất lượng dịch vụ bảo trì và sửa chữa     int64
# Chất lượng thi công                        int64
# Thiết kế tổng thể                          int64
# Chi phí sở hữu                             int64
# dtype: object

# %% [markdown]
# ### KHÁM PHÁ DỮ LIỆU

# %%
# Data to plot
labels = apartment['Giới tính']
sizes = apartment['Giới tính'].value_counts()
explode = (0.1, 0)  # explode 1st slice

sizes.index = pd.CategoricalIndex(sizes.index, categories=[
    'Nam', 'Nữ'
], ordered=True)

sizes = sizes.sort_index()
labels = sizes.index

# Plot
fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(sizes, autopct='%1.1f%%', startangle=140)

# Draw legend
plt.legend(wedges, labels, loc="upper center", bbox_to_anchor=(0.5, -0.0005), ncol=3, frameon=False)
plt.title('Phân bổ giới tính')
plt.savefig('01. pie_chart_gioi_tinh.png', format='png', dpi=300)  # You can change the format and dpi as needed
plt.show()

# Print quantities
for label, size in zip(sizes.index, sizes):
    print(f'{label}: {size}')
# Out:
# Nam: 126
# Nữ: 74

# %%
# Data to plot
labels = apartment['Độ tuổi']
sizes = apartment['Độ tuổi'].value_counts()
explode = (0.1, 0)  # explode 1st slice

sizes.index = pd.CategoricalIndex(sizes.index, categories=[
    'Từ 22 – dưới 30 tuổi', 'Từ 30 – dưới 40 tuổi', 'Trên 40 tuổi'
], ordered=True)

sizes = sizes.sort_index()
labels = sizes.index

# Plot
fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(sizes, autopct='%1.1f%%', startangle=140)

# Draw legend
plt.legend(wedges, labels, loc="upper center", bbox_to_anchor=(0.5, -0.0005), ncol=3, frameon=False)
plt.title('Phân bổ độ tuổi')
plt.savefig('02. pie_chart_do_tuoi.png', format='png', dpi=300)  # You can change the format and dpi as needed
plt.show()

# Print quantities
for label, size in zip(sizes.index, sizes):
    print(f'{label}: {size}')
# Out:
# Từ 22 – dưới 30 tuổi: 101
# Từ 30 – dưới 40 tuổi: 81
# Trên 40 tuổi: 18

# %%
# Data to plot
sizes = apartment['Nghề nghiệp'].value_counts()
sizes.index = pd.CategoricalIndex(sizes.index, categories=['Nhân viên văn phòng', 'Kinh doanh', 'Nội trợ', 'Khác'], ordered=True)
sizes = sizes.sort_index()
labels = sizes.index
explode = (0.1, 0)  # explode 1st slice

# Plot
fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(sizes, autopct='%1.1f%%', startangle=140)

# Draw legend
plt.legend(wedges, labels, loc="upper center", bbox_to_anchor=(0.5, -0.0005), ncol=4, frameon=False)
plt.title('Phân bổ nghề nghiệp')
plt.savefig('03. pie_chart_nghe_nghiep.png', format='png', dpi=300)  # You can change the format and dpi as needed
plt.show()

# Print quantities
for label, size in zip(sizes.index, sizes):
    print(f'{label}: {size}')
# Out:
# Nhân viên văn phòng: 84
# Kinh doanh: 18
# Nội trợ: 53
# Khác: 45

# %%
# Data to plot
sizes = apartment['Tình trạng hôn nhân'].value_counts()
sizes.index = pd.CategoricalIndex(sizes.index, categories=['Đã kết hôn', 'Độc thân'], ordered=True)
sizes = sizes.sort_index()
labels = sizes.index

# Plot
fig, ax = plt.subplots()
wedges, texts, autotexts = ax.pie(sizes, autopct='%1.1f%%', startangle=140)

# Draw legend
plt.legend(wedges, labels, loc="upper center", bbox_to_anchor=(0.5, -0.0005), ncol=4, frameon=False)
plt.title('Phân bổ tình trạng hôn nhân')
plt.savefig('04. pie_chart_hon_nhan.png', format='png', dpi=300)  # You can change the format and dpi as needed
plt.show()

# Print quantities
for label, size in zip(sizes.index, sizes):
    print(f'{label}: {size}')
# Out:
# Đã kết hôn: 45
# Độc thân: 155

# %%
# Data to plot
labels = apartment['Thu nhập hàng tháng']
sizes = apartment['Thu nhập hàng tháng'].value_counts()
colors = ['gold', 'yellowgreen']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, labels=sizes.index, autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Phân bổ thu nhập hằng tháng')
plt.show()

# Print quantities
for label, size in zip(sizes.index, sizes):
    print(f'{label}: {size}')
# Out:
# Từ 10-15 triệu: 72
# Từ 15-20 triệu: 57
# Trên 30 triệu: 49
# Từ 20-30 triệu: 22

# %%
# Data to plot
labels = apartment['Đã từng/sở hữu nhà chung cư']
sizes = labels.value_counts()
colors = ['gold', 'yellowgreen']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, labels=sizes.index, autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Phân bổ đã từng/sở hữu nhà chung cư')
plt.show()

# Print quantities
for label, size in zip(sizes.index, sizes):
    print(f'{label}: {size}')
# Out:
# Chưa từng: 129
# Đã từng: 71

# %%
# Data to plot
labels = apartment['Lý do chọn sở hữu chung cư']
sizes = labels.value_counts()
colors = ['gold', 'yellowgreen']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, labels=sizes.index, autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Phân bổ lý do sở hữu chung cư')
plt.show()

# Print quantities
for label, size in zip(sizes.index, sizes):
    print(f'{label}: {size}')
# Out:
# Mua cho thuê: 75
# Mua kinh doanh: 48
# Mua đầu tư: 42
# Mong muốn sở hữu căn hộ riêng: 35

# %%
# Data to plot
labels = apartment['Loại căn hộ muốn sở hữu']
sizes = labels.value_counts()
colors = ['gold', 'yellowgreen']
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, labels=sizes.index, autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Phân bổ loại căn hộ chung cư muốn sở hữu')
plt.show()

# Print quantities
for label, size in zip(sizes.index, sizes):
    print(f'{label}: {size}')
# Out:
# Căn hộ 2 phòng ngủ (60m2): 120
# Shophouse (>90m2): 36
# Căn hộ 1 phòng ngủ (40m2): 33
# Căn hộ 3 phòng ngủ (72m2): 11

# %%
# Data to plot
labels = apartment['Nguồn thông tin về căn hộ']
sizes = labels.value_counts()
explode = (0.1, 0)  # explode 1st slice

# Plot
plt.pie(sizes, labels=sizes.index, autopct='%1.1f%%', shadow=True, startangle=140)

plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Phân bổ nguồn thông tin về căn hộ')
plt.show()
 
# Print quantities
for label, size in zip(sizes.index, sizes):
    print(f'{label}: {size}')
# Out:
# Báo chí, truyền thông: 104
# Nhân viên Telesale: 51
# Kênh truyền thông của công ty: 26
# Người thân, bạn bè, đồng nghiệp: 19

# %%
safety_benchmarks = apartment['Thi công an toàn']

# Plotting the histogram
plt.hist(safety_benchmarks, bins=10, range=(1, 10), edgecolor='black')
plt.xlabel('Benchmark')
plt.ylabel('Frequency')
plt.xticks(range(1, 11))

plt.title('Thống kê về thi công an toàn')
# Display the plot
plt.show()

# %%
safety_benchmarks = apartment['Bàn giao đúng tiến độ']

# Plotting the histogram
plt.hist(safety_benchmarks, bins=10, range=(1, 10), edgecolor='black')
plt.xlabel('Benchmark')
plt.ylabel('Frequency')
plt.xticks(range(1, 11))

plt.title('Thống kê về tiến độ bàn giao')
# Display the plot
plt.show()

# %%
safety_benchmarks = apartment['Thiết kế đẹp']

# Plotting the histogram
plt.hist(safety_benchmarks, bins=10, range=(1, 10), edgecolor='black')
plt.xlabel('Benchmark')
plt.ylabel('Frequency')
plt.xticks(range(1, 11))

plt.title('Thống kê về thiết kế')

# Display the plot
plt.show()

# %%
safety_benchmarks = apartment['Uy tín doanh nghiệp']

# Plotting the histogram
plt.hist(safety_benchmarks, bins=10, range=(1, 10), edgecolor='black')
plt.xlabel('Benchmark')
plt.ylabel('Frequency')
plt.xticks(range(1, 11))

plt.title('Thống kê về uy tín doanh nghiệp')

# Display the plot
plt.show()

# %%
safety_benchmarks = apartment['Chất lượng dịch vụ bảo trì và sửa chữa']

# Plotting the histogram
plt.hist(safety_benchmarks, bins=10, range=(1, 10), edgecolor='black')
plt.xlabel('Benchmark')
plt.ylabel('Frequency')
plt.xticks(range(1, 11))

plt.title('Thống kê về Chất lượng dịch vụ bảo trì và sửa chữa')

# Display the plot
plt.show()

# %%
safety_benchmarks = apartment['Chất lượng thi công']

# Plotting the histogram
plt.hist(safety_benchmarks, bins=10, range=(1, 10), edgecolor='black')
plt.xlabel('Benchmark')
plt.ylabel('Frequency')
plt.xticks(range(1, 11))

plt.title('Thống kê về Chất lượng thi công')

# Display the plot
plt.show()

# %%
safety_benchmarks = apartment['Thiết kế tổng thể']

# Plotting the histogram
plt.hist(safety_benchmarks, bins=10, range=(1, 10), edgecolor='black')
plt.xlabel('Benchmark')
plt.ylabel('Frequency')
plt.xticks(range(1, 11))

plt.title('Thống kê về thiết kế tổng thể')

# Display the plot
plt.show()

# %%
safety_benchmarks = apartment['Chi phí sở hữu']

# Plotting the histogram
plt.hist(safety_benchmarks, bins=10, range=(1, 10), edgecolor='black')
plt.xlabel('Benchmark')
plt.ylabel('Frequency')
plt.xticks(range(1, 11))

plt.title('Thống kê về chi phí sở hữu')

# Display the plot
plt.show()
